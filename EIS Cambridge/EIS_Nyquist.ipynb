# %%
import pandas as pd
import numpy as np

# %%
import csv

# Ruta del archivo de texto con los datos
input_file = ""

# Leer los datos del archivo de texto
data = []
with open(input_file, 'r') as file:
    # Saltar la primera línea (encabezados)
    next(file)
    for line in file:
        # Separar los valores por espacios y convertirlos a números
        values = [float(val) for val in line.split()]
        data.append(values)

# Nombre del archivo de salida
output_file = "datos_csv.csv"

# Escribir los datos en el archivo CSV
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["time/s", "cycle number", "freq/Hz", "Re(Z)/Ohm", "-Im(Z)/Ohm", "|Z|/Ohm", "Phase(Z)/deg"])
    writer.writerows(data)

print(f"Se ha creado el archivo {output_file} con éxito.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 8
#       6 # Leer los datos del archivo de texto
#       7 data = []
# ----> 8 with open(input_file, 'r') as file:
#       9     # Saltar la primera línea (encabezados)
#      10     next(file)
#      11     for line in file:
#      12         # Separar los valores por espacios y convertirlos a números
#
# File c:\Users\sevil\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: 'https://github.com/SebaVillagra00/ICM2985-SOH-IPRE/blob/main/EIS%20Cambridge/EIS%20data/EIS_state_III_25C01.txt?raw=true'

# %%
url = 'https://github.com/SebaVillagra00/ICM2985-SOH-IPRE/blob/main/EIS%20Cambridge/EIS%20data/EIS_state_III_25C01.txt?raw=true'
df = pd.read_csv(url,sep=' ', header=0, index_col=False)

# %%
df.head(5)
# Out:
#      time/s\t Unnamed: 1 Unnamed: 2              Unnamed: 3  Unnamed: 4  \
# 0  9651.00252        NaN        NaN  1.00000\t20004.45300\t         NaN
# 1  9651.14552        NaN        NaN  1.00000\t15829.12600\t         NaN
# 2  9651.28752        NaN        NaN  1.00000\t12516.70300\t         NaN
# 3  9651.42952        NaN        NaN   1.00000\t9909.44240\t         NaN
# 4  9651.59352        NaN        NaN   1.00000\t7835.48000\t         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN     0.39182         NaN    -0.03055         NaN  ...
# 1         NaN     0.39693         NaN    -0.01230         NaN  ...
# 2         NaN     0.40190         NaN         NaN     0.00234  ...
# 3         NaN     0.40953         NaN         NaN     0.01629  ...
# 4         NaN     0.41789         NaN         NaN     0.02743  ...
#
#    Unnamed: 22  Re(Z)/Ohm\t  Unnamed: 24  -Im(Z)/Ohm\t  Unnamed: 26  \
# 0          NaN          NaN          NaN           NaN          NaN
# 1          NaN          NaN          NaN           NaN          NaN
# 2          NaN          NaN          NaN           NaN          NaN
# 3          NaN          NaN          NaN           NaN          NaN
# 4          NaN          NaN          NaN           NaN          NaN
#
#    Unnamed: 27  |Z|/Ohm\t  Unnamed: 29  Unnamed: 30  Phase(Z)/deg
# 0          NaN        NaN          NaN          NaN           NaN
# 1          NaN        NaN          NaN          NaN           NaN
# 2          NaN        NaN          NaN          NaN           NaN
# 3          NaN        NaN          NaN          NaN           NaN
# 4          NaN        NaN          NaN          NaN           NaN
#
# [5 rows x 32 columns]
